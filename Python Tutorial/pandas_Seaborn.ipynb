# %%
import pandas as pd

df = pd.read_excel('DATA/p01.xlsx')
df.head(3)
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN

# %% [markdown]
# Q. What are counts of Gold, Silver and Bronze Medal ?

# %%
df.Medal.value_counts()
# Out:
# Gold      3292
# Bronze    3208
# Silver    3190
# Name: Medal, dtype: int64

# %% [markdown]
# Q. Give me unique values of Male and Female

# %% [markdown]
# Q. Filter only Ages which are below 3rd Quantile

# %%
# Seeing 3rd quantile

df.Age.describe()
# Out:
# count    67268.000000
# mean        25.644645
# std          6.485239
# min         11.000000
# 25%         21.000000
# 50%         25.000000
# 75%         28.000000
# max         88.000000
# Name: Age, dtype: float64

# %%
# Filtering below 3rd quantile value

df[df['Age']<28.0].head(3)
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN

# %% [markdown]
# Q. Filter Weight Above 25th Percentile

# %% [markdown]
# Q. Filter only Summer season after 1996

# %%
# 2 conditions :
#  Season = Summer 
# AND
#  Year greater than 1996
df[(df['Season']=='Summer') & (df['Year']>1996)].head()
# Out:
#     ID                       Name Sex   Age  Height  Weight     Team  NOC  \
# 1    2                   A Lamusi   M  23.0   170.0    60.0    China  CHN
# 31  12          Jyri Tapani Aalto   M  31.0   172.0    70.0  Finland  FIN
# 33  13         Minna Maarit Aalto   F  34.0   159.0    55.5  Finland  FIN
# 57  18       Timo Antero Aaltonen   M  31.0   189.0   130.0  Finland  FIN
# 79  21  Ragnhild Margrethe Aamodt   F  27.0   163.0     NaN   Norway  NOR
#
#           Games  Year  Season     City      Sport  \
# 1   2012 Summer  2012  Summer   London       Judo
# 31  2000 Summer  2000  Summer   Sydney  Badminton
# 33  2000 Summer  2000  Summer   Sydney    Sailing
# 57  2000 Summer  2000  Summer   Sydney  Athletics
# 79  2008 Summer  2008  Summer  Beijing   Handball
#
#                            Event Medal
# 1   Judo Men's Extra-Lightweight   NaN
# 31       Badminton Men's Singles   NaN
# 33    Sailing Women's Windsurfer   NaN
# 57      Athletics Men's Shot Put   NaN
# ...

# %% [markdown]
# Q. Filter only Judo sport for females

# %% [markdown]
# Q. Group the dataframe by column `Medal` and give me typical value of Height for each column

# %%
# using group by function
grouped = df.groupby('Medal')
grouped.mean()
# Out:
# C:\Users\WARRIOR\AppData\Local\Temp\ipykernel_8280\2625714753.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped.mean()
#                   ID       Age      Height     Weight         Year
# Medal
# Bronze  18558.225686  26.07300  177.708557  73.872603  1973.239401
# Gold    18370.134569  25.92546  177.786392  73.731678  1971.698056
# Silver  18298.491536  26.17278  177.974444  74.233206  1972.149843

# %% [markdown]
# ### **Imp** : **Group By** function is mostly followed by **Aggregate Functions** [Min,Max,Median,Mean,Sum,Count]

# %% [markdown]
# Q. Give me a data which is sorted by Weight

# %%
# sorting values on based of Weight
df.sort_values('Weight',ascending=False).head()
# Out:
#           ID                        Name Sex   Age  Height  Weight     Team  \
# 23155  12177           Ricardo Blas, Jr.   M  21.0   183.0   214.0     Guam
# 23156  12177           Ricardo Blas, Jr.   M  25.0   183.0   214.0     Guam
# 39181  20144  Andrey Ivanovich Chemerkin   M  24.0   183.0   170.0   Russia
# 39182  20144  Andrey Ivanovich Chemerkin   M  28.0   183.0   170.0   Russia
# 63391  32496               Ion Emilianov   M  23.0   202.0   165.0  Moldova
#
#        NOC        Games  Year  Season     City          Sport  \
# 23155  GUM  2008 Summer  2008  Summer  Beijing           Judo
# 23156  GUM  2012 Summer  2012  Summer   London           Judo
# 39181  RUS  1996 Summer  1996  Summer  Atlanta  Weightlifting
# 39182  RUS  2000 Summer  2000  Summer   Sydney  Weightlifting
# 63391  MDA  2000 Summer  2000  Summer   Sydney      Athletics
#
#                                        Event   Medal
# 23155                 Judo Men's Heavyweight     NaN
# ...

# %% [markdown]
# # Seaborn

# %%
# importing required libraries
import seaborn as sns
sns.set()
sns.set(style="darkgrid")
import matplotlib.pyplot as plt

# %% [markdown]
# Q. Is there any trend being followed between Age and Weight?

# %%
sns.lineplot(x=df['Age'],y = df['Weight'])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Weight'>

# %% [markdown]
# Q. Any Outliers in Age?

# %%
sns.boxplot(df['Age'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# Q. Is Age more biased towards younger guys?

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\WARRIOR\AppData\Local\Temp\ipykernel_8280\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <AxesSubplot: xlabel='Age', ylabel='Density'>

# %% [markdown]
# Q. Simple comparison of all column with each other

# %%
sns.pairplot(df)

# %% [markdown]
# Q. Give me heat map of correlation of all numeric column

# %%
# Finding correlation
corr = df.corr()
corr
# Out:
# C:\Users\WARRIOR\AppData\Local\Temp\ipykernel_8280\4176221473.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
#               ID       Age    Height    Weight      Year
# ID      1.000000  0.019051  0.001119 -0.000291 -0.030770
# Age     0.019051  1.000000  0.129005  0.212720 -0.118606
# Height  0.001119  0.129005  1.000000  0.783286  0.044805
# Weight -0.000291  0.212720  0.783286  1.000000  0.019649
# Year   -0.030770 -0.118606  0.044805  0.019649  1.000000

# %%
# HeatMap of correlation
sns.heatmap(df.corr())
# Out:
# C:\Users\WARRIOR\AppData\Local\Temp\ipykernel_8280\2395549193.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %% [markdown]
# Q. What is count of all Medals?

# %%
sns.countplot(x='Medal', data=df)
# Out:
# <AxesSubplot: xlabel='Medal', ylabel='count'>

# %% [markdown]
# Q. What is Average Height for each category of medal?

# %%
sns.barplot(x='Medal', y='Height', data=df)
# Out:
# <AxesSubplot: xlabel='Medal', ylabel='Height'>
